# %% [markdown]
# <a href="https://colab.research.google.com/github/GraziPeregrino/Sedentarism-Inflluences-over-Sleep/blob/main/7200project_clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data import

# %% [markdown]
# ## df:
# The dataframe with all recording detial

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/CS7200project/LONGITUDINAL_by_day.csv")

# %%
df.head()
# Out:
#   PARTICIPANT  DAY_NUM  WEEK_NUM        DATE  Ambulation  \
# 0        CR01       -3        -1  2021-04-16    0.550833
# 1        CR01       -2        -1  2021-04-17    1.486111
# 2        CR01       -1        -1  2021-04-18    0.866667
# 3        CR01        0         0  2021-04-19    1.761667
# 4        CR01        1         0  2021-04-20    0.718889
#
#    Incomplete_Predictions  Nonwear  Sedentary      Sleep  Upright (Other)  \
# 0                0.010833      0.0  14.598611   8.500000         0.339722
# 1                0.010000      0.0  14.153889   8.133333         0.216667
# 2                0.016667      0.0  12.391667  10.341667         0.383333
# 3                0.013333      0.0  13.115000   8.633333         0.476667
# 4                0.016667      0.0  15.331667   7.616944         0.315833
#
#    HOURS_COVERAGE
# 0            24.0
# 1            24.0
# 2            24.0
# 3            24.0
# 4            24.0

# %% [markdown]
# ## group tag
# The dataframe with participents' group tage (treatment group or control group)

# %%
group = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/CS7200project/all_events_by_pt_only_week80.csv")
group.head()
# Out:
#    Unnamed: 0    ID      group    Sedentary  Sedentary_DUR_mean  \
# 0           0  CR01  Treatment  1406.811111            0.064182
# 1           1  CR02  Treatment  1046.246944            0.051501
# 2           2  CR03    Control   963.925556            0.023469
# 3           3  CR04    Control   956.975556            0.034686
# 4           4  CR05  Treatment  1189.493889            0.048912
#
#    Sedentary_DUR_median  Sedentary_DUR_std     Upright  Upright_DUR_mean  \
# 0              0.014167           0.140921   81.453056          0.005090
# 1              0.014444           0.104589   40.243333          0.004712
# 2              0.007222           0.095690  303.975833          0.007514
# 3              0.010833           0.114381  157.539444          0.006255
# 4              0.016667           0.084592   52.356111          0.004545
#
#    Upright_DUR_median  ...  non_sedentary_transitions_upright_per_hour  \
# 0            0.003611  ...                                    5.222063
# 1            0.003611  ...                                    2.747773
# 2            0.003611  ...                                   16.959151
# 3            0.003611  ...                                   10.383177
# 4            0.003611  ...                                    4.325114
#
#    non_sedentary_transitions_ambulation_per_hour  HOURS_COVERAGE  \
# 0                                       3.306052     2443.095556
# 1                                       4.214878     2622.851667
# 2                                       0.726584     2297.048889
# 3                                       1.659490     2177.175556
# 4                                       5.908528     2288.725833
#
#                  start  PREDICTED_WEAR_TIME  UNPREDICTED_OR_NONWEAR_TIME  \
# 0  2021-04-19 00:00:00          2424.412778                    18.682778
# 1  2021-04-19 00:00:00          2621.210556                     1.641111
# 2  2021-04-20 12:22:50          2236.502778                    60.546111
# 3  2021-04-19 00:00:00          1994.604722                   182.570833
# 4  2021-04-19 00:00:00          2287.747222                     0.978611
#
#    Sedentary_adj  Upright_adj  Sleep_adj  Ambulation_adj
# 0       0.580269     0.033597   0.346786        0.039348
# 1       0.399146     0.015353   0.545870        0.039630
# 2       0.430997     0.135916   0.425154        0.007934
# 3       0.479782     0.078983   0.418178        0.023057
# 4       0.519941     0.022885   0.398739        0.058435
#
# [5 rows x 37 columns]

# %%
print(len(pd.unique(group["ID"])))
# Out:
# 30

# %% [markdown]
# ## gender tag
# The dataframe with participents's gender tage, ethnicity, and race. But we only consider the gender in the case so far.

# %%
gender = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/CS7200project/Book3.xlsx")

# %%
gender.head()
# Out:
#   Participant ID     Sex            Ethnicity  \
# 0           CR01  Female  Non-Hispanic/Latino
# 1           CR02    Male  Non-Hispanic/Latino
# 2           CR03  Female  Non-Hispanic/Latino
# 3           CR04    Male  Non-Hispanic/Latino
# 4           CR05  Female  Non-Hispanic/Latino
#
#                                   Race
# 0  Non-Hispanic White or Euro-American
# 1  Non-Hispanic White or Euro-American
# 2  Non-Hispanic White or Euro-American
# 3  Non-Hispanic White or Euro-American
# 4  Non-Hispanic White or Euro-American

# %% [markdown]
# ## Conbine all informations

# %%
group_tag = group[['ID', 'group']].rename(columns = {"ID": "PARTICIPANT", "group":"group"})
# group_tag
with_group = df.merge(group_tag,how = "left")
with_group.head()
# Out:
#   PARTICIPANT  DAY_NUM  WEEK_NUM        DATE  Ambulation  \
# 0        CR01       -3        -1  2021-04-16    0.550833
# 1        CR01       -2        -1  2021-04-17    1.486111
# 2        CR01       -1        -1  2021-04-18    0.866667
# 3        CR01        0         0  2021-04-19    1.761667
# 4        CR01        1         0  2021-04-20    0.718889
#
#    Incomplete_Predictions  Nonwear  Sedentary      Sleep  Upright (Other)  \
# 0                0.010833      0.0  14.598611   8.500000         0.339722
# 1                0.010000      0.0  14.153889   8.133333         0.216667
# 2                0.016667      0.0  12.391667  10.341667         0.383333
# 3                0.013333      0.0  13.115000   8.633333         0.476667
# 4                0.016667      0.0  15.331667   7.616944         0.315833
#
#    HOURS_COVERAGE      group
# 0            24.0  Treatment
# 1            24.0  Treatment
# 2            24.0  Treatment
# 3            24.0  Treatment
# 4            24.0  Treatment

# %%
gender_tag = gender[['Participant ID', 'Sex']].rename(columns = {"Participant ID": "PARTICIPANT"})
# gender_tag.head()
merged_df = with_group.merge(gender_tag,how = "left")
merged_df.head()
# Out:
#   PARTICIPANT  DAY_NUM  WEEK_NUM        DATE  Ambulation  \
# 0        CR01       -3        -1  2021-04-16    0.550833
# 1        CR01       -2        -1  2021-04-17    1.486111
# 2        CR01       -1        -1  2021-04-18    0.866667
# 3        CR01        0         0  2021-04-19    1.761667
# 4        CR01        1         0  2021-04-20    0.718889
#
#    Incomplete_Predictions  Nonwear  Sedentary      Sleep  Upright (Other)  \
# 0                0.010833      0.0  14.598611   8.500000         0.339722
# 1                0.010000      0.0  14.153889   8.133333         0.216667
# 2                0.016667      0.0  12.391667  10.341667         0.383333
# 3                0.013333      0.0  13.115000   8.633333         0.476667
# 4                0.016667      0.0  15.331667   7.616944         0.315833
#
#    HOURS_COVERAGE      group     Sex
# 0            24.0  Treatment  Female
# 1            24.0  Treatment  Female
# 2            24.0  Treatment  Female
# 3            24.0  Treatment  Female
# 4            24.0  Treatment  Female

# %% [markdown]
# # Data Cleaning
#
# ## Get experiment period data
# Because the experiment is 16 weeks and 180 days, so filter out day number and week num are out of the interval.

# %%
filter_day_week_num = merged_df[(merged_df['DAY_NUM'] <= 180) & (merged_df['WEEK_NUM'] <= 15)]
filter_day_week_num = filter_day_week_num[(filter_day_week_num['DAY_NUM'] >= 0) & (filter_day_week_num['WEEK_NUM'] >= 0)]
filter_day_week_num.head()
# Out:
#   PARTICIPANT  DAY_NUM  WEEK_NUM        DATE  Ambulation  \
# 3        CR01        0         0  2021-04-19    1.761667
# 4        CR01        1         0  2021-04-20    0.718889
# 5        CR01        2         0  2021-04-21    1.124167
# 6        CR01        3         0  2021-04-22    0.473056
# 7        CR01        4         0  2021-04-23    2.063333
#
#    Incomplete_Predictions  Nonwear  Sedentary     Sleep  Upright (Other)  \
# 3                0.013333      0.0  13.115000  8.633333         0.476667
# 4                0.016667      0.0  15.331667  7.616944         0.315833
# 5                0.017778      0.0  14.411667  8.075000         0.371389
# 6                0.016667      0.0  14.856667  8.341667         0.311944
# 7                0.021389      0.0  12.088611  8.883333         0.943333
#
#    HOURS_COVERAGE      group     Sex
# 3            24.0  Treatment  Female
# 4            24.0  Treatment  Female
# 5            24.0  Treatment  Female
# 6            24.0  Treatment  Female
# 7            24.0  Treatment  Female

# %% [markdown]
# ## Filter out unreasonable data
# We filter out the sleep hours which is less than 1 and more than 16.
# In Ethan's paper, the interval is 2 to 15. We think the device will compute the less sleep hour than actually we have so 1 hour is make sense also.

# %%
filter_unreasonable_sleep = filter_day_week_num[filter_day_week_num["Sleep"] >= 1]
filter_unreasonable_sleep = filter_unreasonable_sleep[filter_unreasonable_sleep["Sleep"] <= 16]
filter_unreasonable_sleep.head()
# Out:
#   PARTICIPANT  DAY_NUM  WEEK_NUM        DATE  Ambulation  \
# 3        CR01        0         0  2021-04-19    1.761667
# 4        CR01        1         0  2021-04-20    0.718889
# 5        CR01        2         0  2021-04-21    1.124167
# 6        CR01        3         0  2021-04-22    0.473056
# 7        CR01        4         0  2021-04-23    2.063333
#
#    Incomplete_Predictions  Nonwear  Sedentary     Sleep  Upright (Other)  \
# 3                0.013333      0.0  13.115000  8.633333         0.476667
# 4                0.016667      0.0  15.331667  7.616944         0.315833
# 5                0.017778      0.0  14.411667  8.075000         0.371389
# 6                0.016667      0.0  14.856667  8.341667         0.311944
# 7                0.021389      0.0  12.088611  8.883333         0.943333
#
#    HOURS_COVERAGE      group     Sex  Sum_hours
# 3            24.0  Treatment  Female  23.986667
# 4            24.0  Treatment  Female  23.983333
# 5            24.0  Treatment  Female  23.982222
# 6            24.0  Treatment  Female  23.983333
# 7            24.0  Treatment  Female  23.978611

# %% [markdown]
# ## Filter out incomplete
# 1. we sum up the hours of Ambulation, Sedentary,	Sleep, Upright (Other) for each row.
# 2. we filter out the sumation hours which is less than 16.
# 3. we filter the week which has less than 4 days.
# 4. we filter the participant who has less than 80% complete weeks, which is number of weeks should greater 13.

# %%
filter_day_week_num["Sum_hours"] = filter_unreasonable_sleep[['Ambulation','Sedentary','Sleep','Upright (Other)']].sum(axis = 1)
filter_day_week_num.head()
# Out:
#   PARTICIPANT  DAY_NUM  WEEK_NUM        DATE  Ambulation  \
# 3        CR01        0         0  2021-04-19    1.761667
# 4        CR01        1         0  2021-04-20    0.718889
# 5        CR01        2         0  2021-04-21    1.124167
# 6        CR01        3         0  2021-04-22    0.473056
# 7        CR01        4         0  2021-04-23    2.063333
#
#    Incomplete_Predictions  Nonwear  Sedentary     Sleep  Upright (Other)  \
# 3                0.013333      0.0  13.115000  8.633333         0.476667
# 4                0.016667      0.0  15.331667  7.616944         0.315833
# 5                0.017778      0.0  14.411667  8.075000         0.371389
# 6                0.016667      0.0  14.856667  8.341667         0.311944
# 7                0.021389      0.0  12.088611  8.883333         0.943333
#
#    HOURS_COVERAGE      group     Sex  Sum_hours
# 3            24.0  Treatment  Female  23.986667
# 4            24.0  Treatment  Female  23.983333
# 5            24.0  Treatment  Female  23.982222
# 6            24.0  Treatment  Female  23.983333
# 7            24.0  Treatment  Female  23.978611

# %%
filter_incomplete_days = filter_day_week_num[filter_day_week_num["Sum_hours"] >= 16]
filter_incomplete_days.head()
# Out:
#   PARTICIPANT  DAY_NUM  WEEK_NUM        DATE  Ambulation  \
# 3        CR01        0         0  2021-04-19    1.761667
# 4        CR01        1         0  2021-04-20    0.718889
# 5        CR01        2         0  2021-04-21    1.124167
# 6        CR01        3         0  2021-04-22    0.473056
# 7        CR01        4         0  2021-04-23    2.063333
#
#    Incomplete_Predictions  Nonwear  Sedentary     Sleep  Upright (Other)  \
# 3                0.013333      0.0  13.115000  8.633333         0.476667
# 4                0.016667      0.0  15.331667  7.616944         0.315833
# 5                0.017778      0.0  14.411667  8.075000         0.371389
# 6                0.016667      0.0  14.856667  8.341667         0.311944
# 7                0.021389      0.0  12.088611  8.883333         0.943333
#
#    HOURS_COVERAGE      group     Sex  Sum_hours
# 3            24.0  Treatment  Female  23.986667
# 4            24.0  Treatment  Female  23.983333
# 5            24.0  Treatment  Female  23.982222
# 6            24.0  Treatment  Female  23.983333
# 7            24.0  Treatment  Female  23.978611

# %%
print(len(filter_day_week_num))
print(len(filter_incomplete_days))
# Out:
# 4336
# 3251

# %%
filter_incomplete_weeks = filter_incomplete_days.groupby(["PARTICIPANT","WEEK_NUM"]).filter(lambda x: len(x) >= 4)
filter_incomplete_weeks.head()
# Out:
#   PARTICIPANT  DAY_NUM  WEEK_NUM        DATE  Ambulation  \
# 3        CR01        0         0  2021-04-19    1.761667
# 4        CR01        1         0  2021-04-20    0.718889
# 5        CR01        2         0  2021-04-21    1.124167
# 6        CR01        3         0  2021-04-22    0.473056
# 7        CR01        4         0  2021-04-23    2.063333
#
#    Incomplete_Predictions  Nonwear  Sedentary     Sleep  Upright (Other)  \
# 3                0.013333      0.0  13.115000  8.633333         0.476667
# 4                0.016667      0.0  15.331667  7.616944         0.315833
# 5                0.017778      0.0  14.411667  8.075000         0.371389
# 6                0.016667      0.0  14.856667  8.341667         0.311944
# 7                0.021389      0.0  12.088611  8.883333         0.943333
#
#    HOURS_COVERAGE      group     Sex  Sum_hours
# 3            24.0  Treatment  Female  23.986667
# 4            24.0  Treatment  Female  23.983333
# 5            24.0  Treatment  Female  23.982222
# 6            24.0  Treatment  Female  23.983333
# 7            24.0  Treatment  Female  23.978611

# %%
print(len(filter_incomplete_days))
print(len(filter_incomplete_weeks))
# Out:
# 3251
# 3044

# %%
print(len(pd.unique(filter_incomplete_days["PARTICIPANT"])))
print(len(pd.unique(filter_incomplete_weeks["PARTICIPANT"])))
# Out:
# 44
# 43

# %%
# prompt: get the differ rows between  filter_incomplete_days and filter_incomplete_weeks

diff = filter_incomplete_days.merge(filter_incomplete_weeks,how = "outer",indicator = True)
diff = diff[diff["_merge"] == "left_only"]
diff.head()
# Out:
#     PARTICIPANT  DAY_NUM  WEEK_NUM        DATE  Ambulation  \
# 527        CR06       28         4  2021-05-17    0.128611
# 528        CR06       31         4  2021-05-20    0.462778
# 539        CR06       62         8  2021-06-20    0.230833
# 540        CR06       67         9  2021-06-25    0.686944
# 541        CR06       73        10  2021-07-01    0.337222
#
#      Incomplete_Predictions  Nonwear  Sedentary      Sleep  Upright (Other)  \
# 527                0.003611    0.000   5.484444  10.416944         0.150000
# 528                0.016667    0.000  12.732500  10.008333         0.779722
# 539                0.010833    1.075  11.555278  10.633611         0.469722
# 540                0.010000    0.000  11.069722  11.950278         0.275000
# 541                0.015000    0.000   9.512778  10.025000         0.501944
#
#      HOURS_COVERAGE group     Sex  Sum_hours     _merge
# 527       16.183611   NaN  Female  16.180000  left_only
# 528       24.000000   NaN  Female  23.983333  left_only
# 539       23.975278   NaN  Female  22.889444  left_only
# 540       23.991944   NaN  Female  23.981944  left_only
# 541       20.391944   NaN  Female  20.376944  left_only

# %% [markdown]
# So for the step of remove weeks with number of days, we removed the incompleted weeks but not the whole data of the participant. We can see the filter result from the table "diff", it shows there are more than one participent data be cleaned, but only one participant less by the step.

# %%
# prompt: filter out the participant how has less than 12 unique week_num

unique_week_num = filter_incomplete_weeks.groupby(["PARTICIPANT"])["WEEK_NUM"].nunique()
unique_week_num = unique_week_num[unique_week_num >= 12]
clean_data = filter_incomplete_weeks[filter_incomplete_weeks["PARTICIPANT"].isin(unique_week_num.index)]
# clean_data.head()

# %%
print(len(filter_incomplete_weeks))
print(len(clean_data))

print(len(pd.unique(filter_incomplete_weeks["PARTICIPANT"])))
print(len(pd.unique(clean_data["PARTICIPANT"])))
# Out:
# 3044
# 2525
# 43
# 28
